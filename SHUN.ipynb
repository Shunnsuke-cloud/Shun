# %% [markdown]
# <a href="https://colab.research.google.com/github/Shunnsuke-cloud/Shun/blob/main/SHUN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__) # Changed _version_ to __version__
# Out:
# 2.17.1

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model=Sequential()
model.add(Dense(64,activation="relu"))

# %%
from tensorflow.keras.layers import Conv2D
model.add(Conv2D(32, kernel_size=(3,3), activation="relu", input_shape=(28,28,1))) # Changed kernel__size to kernel_size and input__shape to input_shape
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.layers import MaxPooling2D
model.add(MaxPooling2D(pool_size=(2,2)))

# %%
# ipython-input-9-a856a85c0c07 (Corrected)
from tensorflow.keras.layers import Dense  # Keep this line to import Dense layer
# from tensorflow.keras.layers import Sequential  # Remove or comment out this incorrect import

# Sequential is already imported in a previous cell from tensorflow.keras.models.
# If you need to re-initialize the model, use:
model = tf.keras.models.Sequential([
    Dense(64, activation="relu", input_shape=(784,)),
    Dense(10, activation="softmax")
])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 64)                  │          50,240 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
# ...

# %%
model.compile(
    optimizer="adam",     # 最適化アルゴリズム。勾配降下法の改良版で、学習速度が速くよく使用される。
    loss="categorical_crossentropy",  # 損失関数。カテゴリカル分類問題用で、正解ラベルと予測値の差を計算。
    metrics=["accuracy"]  # 精度（accuracy）を評価指標として設定。予測が正解したデータの割合を示す。
)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Flatten,Dense
from tensorflow.keras.datasets import  mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train=x_train.reshape(-1,28,28,1).astype("float32")/255  # Changed 'floa32' to 'float32'
x_test=x_test.reshape(-1,28,28,1).astype("float32")/255  # Changed 'floa32' to 'float32'
y_train=to_categorical(y_train,10)
y_test=to_categorical(y_test,10)
model=Sequential([
    Conv2D(32,kernel_size=(3,3),activation="relu",input_shape=(28,28,1)),
    MaxPooling2D(pool_size=(2,2)),
    Flatten(),
    Dense(128,activation="relu"),
    Dense(10,activation="softmax")
])
model.compile(optimizer=Adam(learning_rate=0.001), # Corrected typo: lerning_rate to learning_rate
              loss="categorical_crossentropy",
              metrics=["accuracy"])
model.fit(x_train,y_train,batch_size=128,epochs=10,validation_data=(x_test,y_test)) # Corrected typo: velidation_deta to validation_data
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 78ms/step - accuracy: 0.8758 - loss: 0.4392 - val_accuracy: 0.9728 - val_loss: 0.0862
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 33s 71ms/step - accuracy: 0.9783 - loss: 0.0732 - val_accuracy: 0.9807 - val_loss: 0.0563
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 72ms/step - accuracy: 0.9864 - loss: 0.0455 - val_accuracy: 0.9839 - val_loss: 0.0433
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 38s 66ms/step - accuracy: 0.9913 - loss: 0.0317 - val_accuracy: 0.9851 - val_loss: 0.0441
# Epoch 5/10
# ...

# %%
import matplotlib.pyplot as plt
history=model.fit(x_train,y_train,batch_size=128,epochs=10,validation_split=0.2)
print(history.history.keys()) # Assuming you want to see the available keys
epochs=range(1,len(history.history["accuracy"])+1)
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(epochs,history.history["accuracy"],"b",label="Training accuracy")
plt.plot(epochs,history.history["val_accuracy"],"r",label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.subplot(1,2,2)
plt.plot(epochs,history.history["loss"],"b",label="Training loss")
plt.plot(epochs,history.history["val_loss"],"r",label="Validation loss")
plt.title("Training and validation loss") # corrected title
plt.xlabel("Epochs")
plt.ylabel("loss")
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 25s 67ms/step - accuracy: 0.9990 - loss: 0.0048 - val_accuracy: 0.9987 - val_loss: 0.0057
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 40s 66ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.9987 - val_loss: 0.0050
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 41s 67ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9989 - val_loss: 0.0039
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 24s 64ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9992 - val_loss: 0.0034
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 25s 67ms/step - accuracy: 1.0000 - loss: 3.9173e-04 - val_accuracy: 0.9992 - val_loss: 0.0033
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 25s 68ms/step - accuracy: 1.0000 - loss: 1.9327e-04 - val_accuracy: 0.9993 - val_loss: 0.0030
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 26s 69ms/step - accuracy: 1.0000 - loss: 1.4184e-04 - val_accuracy: 0.9992 - val_loss: 0.0032
# Epoch 8/10
# ...
